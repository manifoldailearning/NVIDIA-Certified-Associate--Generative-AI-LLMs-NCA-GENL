# %%
import tensorflow as tf
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full,y_train_full),(X_test,y_test) = fashion_mnist
X_train,y_train = X_train_full[:-5000],y_train_full[:-5000]
X_valid,y_valid = X_train_full[-5000:],y_train_full[-5000:]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %%
#nomralization
import numpy as np

# %%
np.max(X_train),np.min(X_train)
# Out:
# (255, 0)

# %%
X_train, X_valid, X_test = X_train / 255., X_valid / 255., X_test / 255.

# %%
np.max(X_train),np.min(X_train)
# Out:
# (1.0, 0.0)

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[0], cmap='binary')
plt.show()

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
n_rows = 4
n_cols = 5
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]])
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Flatten

model = Sequential()
model.add(InputLayer(input_shape=[28,28]))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(75, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 75)                7575
#
#  dense_2 (Dense)             (None, 10)                760
#
# =================================================================
# Total params: 86,835
# Trainable params: 86,835
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 13s 6ms/step - loss: 0.7966 - accuracy: 0.7360 - val_loss: 0.5505 - val_accuracy: 0.8084
# Epoch 2/30
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.5123 - accuracy: 0.8216 - val_loss: 0.4729 - val_accuracy: 0.8344
# Epoch 3/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4620 - accuracy: 0.8383 - val_loss: 0.4447 - val_accuracy: 0.8408
# Epoch 4/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.4327 - accuracy: 0.8467 - val_loss: 0.4195 - val_accuracy: 0.8482
# Epoch 5/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4118 - accuracy: 0.8549 - val_loss: 0.4090 - val_accuracy: 0.8560
# Epoch 6/30
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.3964 - accuracy: 0.8600 - val_loss: 0.3901 - val_accuracy: 0.8580
# Epoch 7/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3824 - accuracy: 0.8646 - val_loss: 0.3756 - val_accuracy: 0.8624
# Epoch 8/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3715 - accuracy: 0.8691 - val_loss: 0.3864 - val_accuracy: 0.8618
# Epoch 9/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3621 - accuracy: 0.8703 - val_loss: 0.3701 - val_accuracy: 0.8626
# Epoch 10/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.3521 - accuracy: 0.8744 - val_loss: 0.3654 - val_accuracy: 0.8680
# Epoch 11/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3448 - accuracy: 0.8765 - val_loss: 0.3673 - val_accuracy: 0.8682
# Epoch 12/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3383 - accuracy: 0.8792 - val_loss: 0.3690 - val_accuracy: 0.8678
# Epoch 13/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3302 - accuracy: 0.8817 - val_loss: 0.3589 - val_accuracy: 0.8668
# Epoch 14/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3249 - accuracy: 0.8835 - val_loss: 0.3545 - val_accuracy: 0.8690
# Epoch 15/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.3192 - accuracy: 0.8855 - val_loss: 0.3461 - val_accuracy: 0.8734
# Epoch 16/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3129 - accuracy: 0.8879 - val_loss: 0.3579 - val_accuracy: 0.8700
# Epoch 17/30
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3071 - accuracy: 0.8904 - val_loss: 0.3455 - val_accuracy: 0.8728
# Epoch 18/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3026 - accuracy: 0.8912 - val_loss: 0.3505 - val_accuracy: 0.8712
# Epoch 19/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2965 - accuracy: 0.8929 - val_loss: 0.3379 - val_accuracy: 0.8784
# Epoch 20/30
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.2920 - accuracy: 0.8939 - val_loss: 0.3335 - val_accuracy: 0.8776
# Epoch 21/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2877 - accuracy: 0.8966 - val_loss: 0.3345 - val_accuracy: 0.8758
# Epoch 22/30
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.2833 - accuracy: 0.8979 - val_loss: 0.3548 - val_accuracy: 0.8714
# Epoch 23/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2791 - accuracy: 0.9003 - val_loss: 0.3248 - val_accuracy: 0.8794
# Epoch 24/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2755 - accuracy: 0.9006 - val_loss: 0.3407 - val_accuracy: 0.8774
# Epoch 25/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2705 - accuracy: 0.9024 - val_loss: 0.3260 - val_accuracy: 0.8796
# Epoch 26/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2673 - accuracy: 0.9037 - val_loss: 0.3386 - val_accuracy: 0.8812
# Epoch 27/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2641 - accuracy: 0.9051 - val_loss: 0.3244 - val_accuracy: 0.8806
# Epoch 28/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2599 - accuracy: 0.9063 - val_loss: 0.3347 - val_accuracy: 0.8828
# Epoch 29/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2570 - accuracy: 0.9078 - val_loss: 0.3210 - val_accuracy: 0.8868
# Epoch 30/30
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2540 - accuracy: 0.9086 - val_loss: 0.3290 - val_accuracy: 0.8848
